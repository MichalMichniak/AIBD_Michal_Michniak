# %% [markdown]
# ##  Regresja liniowa
#
# Regresja liniowa to tworzenie modeli przedstawiających wielkość, której wartość chcemy przewidzieć (zmienna zależna) jako kombinację liniową predyktorów (zmiennych zależnych).
#
# Struktura modelu ma postać
#
# $$\tilde{y} = \beta_0 + \beta_1 x_1 + \beta_2 x_2 +\ldots+ \beta_n x_n$$
#
# lub w formie macierzowej
#
# $$\tilde{\mathbf{y}} = \mathbf{[1\  X ]} \beta$$
#
# gdzie wektor wartości zmiennych zależnych jest przewidywany na podstawie macierzy danych i wektora współczynników $\beta$.
#
# Współczynnik $\beta_0$ w nomentkalturze anglojęzycznej jest nazywany *intercept* ponieważ jest to punkt przecięcia się z osią $y$ gdy wszystkie predyktory są równe 0.
#
# Aby wyznaczyć parametry modelu liniowego potrzebujemy wektora danych uczących, tj. znanych nam wartości zmiennej zależnej  $\mathbf{y}$ oraz odpowiadająxcej mu macierzy predyktorów $\mathbf{X}$. Macierz predyktorów nosi nazwę *design matrix*, i bardzo użytyeczne do jej wyznaczenia (w oparciu o dane w forme dataframe) jest pakiet [patsy](https://patsy.readthedocs.io/en/latest/quickstart.html), a w szczególności funkcja ```dmatrices```.
#
#
# Model regresyjny ma mocne umocowanie statystyczne, jednak w ramach zajęć będziemy traktować go machinistycznie jak jedną z metod uczenia maszynowego. Do tworzenia takich modeli służy klasa ```LinearRegression```
#
# Do analizy regresji liniowej wykorzystywać będziemy pakiet ```scikit-learn``` oraz zawarte w nim klasy, głównie w modułach ```linear_model```, ```metrics``` oraz ```model_selection```.
#
# ### Dane uczące i dane testowe
#
# Zazwyczaj rozwiązując problem nie mamy dostępu do dodatkowych danych testowych uzupełniających nasze dane uczące. Dlatego też, popularną praktyką jest podzielenie posiadanego zbioru danych w sposób losowy na dwa zbiory: uczący i testowy. Do tego służy funkcja ```train_test_split``` z modułu ```model_selection```.

# %% [markdown]
# ### Zadanie 1
# Na podstawie danych zawartych w pliku SCORES.csv wykonaj i oceń regresję liniową, gdzie Twoją daną niezależną (predyktorem) będą godziny poświęcone na przygotowanie, a wynikową uzyskane punkty. Wykonanie zadania powinno składać się z następujących kroków:
# 1. Zaimportowanie niezbędnych bibliotek w szczególności tych tworzących modele liniowe z "scikit-learn", a także biblioteki do operacji na danych oraz tworzenia wykresów.
# 2. Odczytaj dane z pliku SCORES.csv. Pomocne w interpretacji danych są metody: head(), describe(), shape.
# 3. Wykonaj wstępny wykres uzyskanych danych (typu "scatter")
# 4. Dokonaj podziału danych na zbiory danych niezależnych (wejściowe, X) oraz zaleznych (wyjściowe, y) dla swojego modelu, a następnie podziel zbiór na dane testowe i treningowe (30%)
# 5. Utwróz model regresji liniowej za pomocą sklearn.
# 6. Wypisz i przeanalizuj wyliczone wskaźniki dla modelu: coef_ oraz intercept_. Czym one są i do czego służą?
# 7. Wykorzystając stworozny model dokonaj predykcji dla części testowej X. Porównaj wynik (y_pred) z posiadanymi danymi (y_test).
# 8. Wykonaj wykres konfrontujący dane testowe (X_test, y_test; typu "scatter") oraz predykcje (X_test, y_pred; linia prosta)
# 9. Dokonaj walidacji uzyskanych predykcji wykorzystując metryki: średni błąd bezwzględny (Mean Absolute Error), błąd średniokwadratowy (Mean Squared Error) oraz pierwiastek błędu średniokwadratowego (Root Mean Squared Error).
#
# Następnie utworzony skrypt wykorzystaj na danych zawartych w SBP.csv, gdzie predyktorem będzie wiek, a wynikiem ciśnienie (SBP). Czy uzyskane wyniki z modelu są równie zadowalające?

# %% [markdown]
# ### Zadanie 2
# Na podstawie danych zawartych w pliku PETROL.csv wykonaj i oceń regresję liniową. Jako daną zależną wykorzystaj zużycie paliwa, a pozostałe - jako predyktory. Wykonanie zadania powinno składać się z kroków podobnych do tych z zadania poprzedniego.
#
# Czy uzyskane wyniki predykcji modelu są dobre? Co mogło mieć pozytywny/negatywny wpływ na taki wynik?

# %% [markdown]
# ### Regresja logistyczna
#
# Naturalnym rozwojem modeli linowych, są uogólnione modele liniowe (*generalized linear models*).
#
# Ich przewodnią ideą jest to, że zamiast reprezentować zmienną zależną jako kombinację liniową niezależnych, staramy się stworzyć model liniowy pewnej funkcji zmiennej zależnej.
#
# $$ f(y) =  \beta_0 + \beta_1 x_1 + \beta_2 x_2 +\ldots+ \beta_n x_n$$
#
# wymaga się, aby funkcja ta była odwracalna, dzięki czemu
#
# $$ y = f^{-1} ( \beta_0 + \beta_1 x_1 + \beta_2 x_2 +\ldots+ \beta_n x_n)$$
#
# Takie przekształcenie stosujemy wtedy, gdy zbiór wartości zmiennej zależnej nie jest całym zbiorem liczb rzeczywistych tylko jest w jakiś sposób ograniczony. Na przykład do przedziału $[0,1]$, do wartości dodatnich lub wartości całkowitych. W tens posób można wybrać funkcję $f$, której dziedziną jest zbiór wartości $y$ zaś obrazem jest zbiór liczb rzeczywistych.
#
# Jedną z takich funkcji jest tzw. funkcja logistyczna, która odpowiada zbiorowi $[0,1]$ przez co często jest wykorzystywana do analizy prawdopodobieństwa przynależności do danej klasy, lub też inaczej jako klasyfikator.
#
# W takiej sytuacji zmienne zależne powinny przyjmować wyłącznie wartości $0$ i $1$ co odpowiada temu czy dany punkt należy do interesującej klasy. Model logistyczny poznwala na określenie estymaty prawdopodobieństwa, czy punkt należy czy nie do danej klasy.
#
# Do tworzenia modeli logistycznyc służy klasa: ```LogisticRegression```

# %% [markdown]
# ### Zadanie 3
#
# Na podstawie danych zawartych w pliku HEART.csv wykonaj i oceń regresję logistyczną, gdzie Twoją daną zależną jest kolumna "num". Wykonanie zadania powinno składać się z następujących kroków:
#
# 1. Zaimportowanie niezbędnych bibliotek w szczególności tych tworzących modele liniowe z "scikit-learn", a także biblioteki do operacji na danych oraz tworzenia wykresów.
# 2. Odczytanie danych z pliku HEART.csv. Pomocne w interpretacji danych są metody: head(), describe(), shape.
# 3. Przetworzenie danych, tj: oznaczenie braku danych ("?") na NaN, usunięcię kolumn zawierających zbyt dużo brakujących danych (3 kolumny), usunięcie wierszy z brakującymi wartościami.
# 4. Zakoduj niezależne zmienne kategorialne np: jako wartości "dummy", za pomoca metody get_dummies(). Zmienne kategorialne to takie, które reprezentuja przynależność do kategorii. W przypadku naszych odfiltrowanych danych będą to kolumny: cp, restecg, fbs, sex, exang. Jako, że trzy ostatnie już zapisane są w formie 0 i 1 tylko cp i restecg wymagają tej operacji.
# 5. Dokonaj podziału danych na zbiory danych niezależnych (wejściowe, X) oraz zależnych (wyjściowe, y) dla swojego modelu, a następnie podziel zbiór na dane testowe i treningowe (20%).
# 6. Utwróz model regresji logistycznej.
# 7. Oceń wynik za pomocą dostępnych metryk (np: metody związane z modelem czy classification_report() z sklearn)
#
# Możesz również spróbować ustandaryzować dane (np: poprzez skalowanie) po podziale na zbiory treningowy i testowy.

# %% [markdown]
# ## Zadanie 1

# %% [markdown]
# ### SCORES.csv

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt

df = pd.read_csv("SCORES.csv")

df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
plt.scatter(df["Hours"], df["Scores"])
plt.grid()
plt.title("wykres wynikow w zaleznosci od liczby\ngodzin poswieconych na nauke")
plt.xlabel("liczba godzin [h]")
plt.ylabel("wynik [%]")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,y_train = train_test_split(df,train_size=0.7)
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(np.array(X_train["Hours"]).reshape([-1,1]),np.array(X_train["Scores"]))
b1 = model.coef_[0]
b0 = model.intercept_
print(f"b0 = {b0}\nb1 = {b1}")
plt.plot([0,10],[b0,b0+b1*10], label="model liniowy")
plt.scatter(X_train["Hours"], X_train["Scores"],label= "przypadki ucząca")
plt.scatter(y_train["Hours"], y_train["Scores"],label= "przypadki testowe")
plt.grid()
plt.title("wykres wynikow w zaleznosci od liczby\ngodzin poswieconych na nauke")
plt.xlabel("liczba godzin [h]")
plt.ylabel("wynik [%]")
plt.xlim([0,10])
plt.ylim([0,100])
plt.legend()
plt.show()
predic = model.predict(np.array(y_train["Hours"]).reshape([-1,1]))
plt.scatter(y_train["Hours"], y_train["Scores"],label= "dokładne wyniki")
plt.scatter(y_train["Hours"], predic,label= "wyniki predykcji")
plt.grid()
plt.title("wykres porównujący uzyskane wyniki testowe predykcji z dokładnymi wynikami testowymi")
plt.xlabel("liczba godzin [h]")
plt.ylabel("wynik [%]")
plt.xlim([0,10])
plt.ylim([0,100])
plt.legend()
plt.show()

AE = np.sum(np.abs(predic-y_train["Scores"]))/len(predic)
MSE = np.sum((predic-y_train["Scores"])**2)/len(predic)
RMS = np.sqrt(MSE)
print(f"Absolute error = {AE}\nMSE = {MSE}\nRMS = {RMS}")
# Out:
# b0 = 1.7961446793485436
# b1 = 9.959559959394449
# Absolute error = 4.587087461932298
# MSE = 22.33184073193894
# RMS = 4.725657703636494

# %% [markdown]
# ### SBP.csv

# %%
df = pd.read_csv("SBP.csv")

df.describe()
# Out:
#              Age         SBP
# count  19.000000   19.000000
# mean   64.947368  129.421053
# std     7.214751   13.454928
# min    54.000000  111.000000
# 25%    60.500000  119.000000
# 50%    63.000000  129.000000
# 75%    68.500000  137.000000
# max    79.000000  163.000000

# %%
plt.scatter(df["Age"], df["SBP"])
plt.grid()
plt.title("wykres ciśnienia(SBP)  w zaleznosci od wieku")
plt.xlabel("liczba godzin [h]")
plt.ylabel("wynik [%]")
plt.show()

# %%
X_train,y_train = train_test_split(df,train_size=0.7)
model = LinearRegression()
model.fit(np.array(X_train["Age"]).reshape([-1,1]),np.array(X_train["SBP"]))
b1 = model.coef_[0]
b0 = model.intercept_
print(f"b0 = {b0}\nb1 = {b1}")
plt.plot([0,1000],[b0,b0+b1*1000], label="model liniowy")
plt.scatter(X_train["Age"], X_train["SBP"],label= "przypadki ucząca")
plt.scatter(y_train["Age"], y_train["SBP"],label= "przypadki testowe")
plt.grid()
plt.title("wykres ciśnienia(SBP)  w zaleznosci od wieku")
plt.xlabel("wiek")
plt.ylabel("ciśnienie SBP")
plt.legend()
plt.xlim([50,80])
plt.ylim([110,160])
plt.show()
predic = model.predict(np.array(y_train["Age"]).reshape([-1,1]))
plt.scatter(y_train["Age"], y_train["SBP"],label= "dokładne wyniki")
plt.scatter(y_train["Age"], predic,label= "wyniki predykcji")
plt.grid()
plt.title("wykres porównujący uzyskane wyniki testowe predykcji\nz dokładnymi wynikami testowymi")
plt.xlabel("liczba godzin [h]")
plt.ylabel("wynik [%]")
plt.legend()
plt.show()

AE = np.sum(np.abs(predic-y_train["SBP"]))/len(predic)
MSE = np.sum((predic-y_train["SBP"])**2)/len(predic)
RMS = np.sqrt(MSE)
print(f"Absolute error = {AE}\nMSE = {MSE}\nRMS = {RMS}")
# Out:
# b0 = 35.06693620844561
# b1 = 1.4248277927523219
# Absolute error = 10.001821902765293
# MSE = 126.60515849844701
# RMS = 11.251895773532876

# %% [markdown]
# ### Wnioski zad 1
# uzyskane wyniki w predykcji uzyskanych wyników ze względu na liczbę godzin spędzonych na naukę są zadowalające z uwagi na dość liniowy charakter danych tzn przy małym odchyleniu od wybranej wartości z danych jest mała różnica w uzyskanym wyniku oraz jest ona średnio proporcionalna do odchylenia od danej wartości (odchylenie standardowe jest małe przy proporcionalnym wzroście wartości). zupełnie inacej jest w przypadku pomiarów ciśnienia gdzie jet widoczna wyraźna korelacja wieku do uzyskanego ciśnienia lecz istnieje duży rozrzut danych pomiędzy kolejnymi próbkami dlatego błąd jest dość duży.

# %% [markdown]
# ## Zadanie 2

# %%
df = pd.read_csv("PETROL.csv")

df.describe()
# Out:
#        Podatek_paliwowy  Sredni_przychod  Utwardzone_autostrady  \
# count         48.000000        48.000000              48.000000
# mean           7.668333      4241.833333            5565.416667
# std            0.950770       573.623768            3491.507166
# min            5.000000      3063.000000             431.000000
# 25%            7.000000      3739.000000            3110.250000
# 50%            7.500000      4298.000000            4735.500000
# 75%            8.125000      4578.750000            7156.000000
# max           10.000000      5342.000000           17782.000000
#
#        Procent_ludnosci_z_prawem_jazdy  Zuzycie_paliwa
# count                        48.000000       48.000000
# mean                          0.570333      576.770833
# std                           0.055470      111.885816
# min                           0.451000      344.000000
# 25%                           0.529750      509.500000
# 50%                           0.564500      568.500000
# ...

# %%
X_train,y_train = train_test_split(df,train_size=0.7)
model = LinearRegression()
model.fit(X_train[["Podatek_paliwowy","Sredni_przychod","Utwardzone_autostrady","Procent_ludnosci_z_prawem_jazdy"]],np.array(X_train["Zuzycie_paliwa"]))
bi = model.coef_
b0 = model.intercept_
print(f"b0 = {b0}\nb_i = {bi}")
predic = model.predict(y_train[["Podatek_paliwowy","Sredni_przychod","Utwardzone_autostrady","Procent_ludnosci_z_prawem_jazdy"]])
AE = np.sum(np.abs(predic-y_train["Zuzycie_paliwa"]))/len(predic)
MSE = np.sum((predic-y_train["Zuzycie_paliwa"])**2)/len(predic)
RMS = np.sqrt(MSE)
print(f"Absolute error = {AE}\nMSE = {MSE}\nRMS = {RMS}")
# Out:
# b0 = 505.2775132722346
# b_i = [-4.29858360e+01 -6.70019272e-02 -6.23581007e-03  1.26855858e+03]
# Absolute error = 56.456263386311925
# MSE = 4639.124476865836
# RMS = 68.11111859943159

# %%
for i in ["Podatek_paliwowy","Sredni_przychod","Utwardzone_autostrady","Procent_ludnosci_z_prawem_jazdy"]:
    plt.scatter(df["Zuzycie_paliwa"], df[i])
    plt.grid()
    plt.title(f"wykres Zuzycia paliwa  w zaleznosci od {i}")
    plt.xlabel(f"{i}")
    plt.ylabel("zużycie paliwa")
    plt.show()

# %%
model = LinearRegression()
model.fit(X_train[["Podatek_paliwowy","Sredni_przychod","Procent_ludnosci_z_prawem_jazdy"]],np.array(X_train["Zuzycie_paliwa"]))
bi = model.coef_
b0 = model.intercept_
print(f"b0 = {b0}\nb_i = {bi}")
predic = model.predict(y_train[["Podatek_paliwowy","Sredni_przychod","Procent_ludnosci_z_prawem_jazdy"]])
AE = np.sum(np.abs(predic-y_train["Zuzycie_paliwa"]))/len(predic)
MSE = np.sum((predic-y_train["Zuzycie_paliwa"])**2)/len(predic)
RMS = np.sqrt(MSE)
print(f"Absolute error = {AE}\nMSE = {MSE}\nRMS = {RMS}")
# Out:
# b0 = 276.0028818897583
# b_i = [-2.51681293e+01 -8.01922207e-02  1.47107044e+03]
# Absolute error = 50.58456682362517
# MSE = 4072.8241673266534
# RMS = 63.818681961684646

# %% [markdown]
# ### Wnioski zad 2
# jakość rozwiązań testowych w dużej mierze zależy od wylosowanego zbioru testowego dlatego uważam że model liniowy nie do końca spełnia oczekiwania odnośnie predykcji. napewno duży wpływ na błąd średniokwadratowy mają dane oddalone od normalnych wartości pewnego rodzaju anomalie w zbiorze danych np. 3 dane na wykresie zużycia paliwa i średnim przychodem z największym zużyciem paliwa. Dodatkowo cecha "Utwardzone_Atostrady" nie posiada zbyt dużej korelacji z cechą "Zuzycie_paliwa" względem większości metryk do porównywania predykcji (oczywiście z dokładnością do wylosowanych danych)

# %% [markdown]
# ## Zadanie 3

# %%
df = pd.read_csv("HEART.csv")
df = df.replace("?",np.NaN)
df.columns = ["age",'sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num']
#print(df.count())
df = df[["age",'sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','num']]
df = df.dropna()
df.describe(include ="all")

dummies = pd.get_dummies(df["cp"])
df.drop(columns="cp",inplace=True)
dummies.columns = [f"cp_{i}" for i in range(len(dummies.columns))]
df = df.join(dummies)
dummies = pd.get_dummies(df["restecg"])
df.drop(columns="restecg",inplace=True)
dummies.columns = [f"restecg_{i}" for i in range(len(dummies.columns))]
df = df.join(dummies).astype(int)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261 entries, 0 to 293
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        261 non-null    int32
#  1   sex        261 non-null    int32
#  2   trestbps   261 non-null    int32
#  3   chol       261 non-null    int32
#  4   fbs        261 non-null    int32
#  5   thalach    261 non-null    int32
#  6   exang      261 non-null    int32
#  7   oldpeak    261 non-null    int32
#  8   num        261 non-null    int32
#  9   cp_0       261 non-null    int32
#  10  cp_1       261 non-null    int32
#  11  cp_2       261 non-null    int32
#  12  cp_3       261 non-null    int32
#  13  restecg_0  261 non-null    int32
#  14  restecg_1  261 non-null    int32
#  15  restecg_2  261 non-null    int32
# dtypes: int32(16)
# memory usage: 26.5 KB

# %%
from sklearn.model_selection import train_test_split
X_train,y_train = train_test_split(df,train_size=0.8)
X_zal,X_nzal = X_train['num'],X_train.drop('num', axis=1)
y_zal,y_nzal = y_train['num'],y_train.drop('num', axis=1)
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_nzal,X_zal)
pred = model.predict(y_nzal)
from sklearn.metrics import classification_report
print(classification_report(y_zal,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.92      0.79        24
#            1       0.90      0.66      0.76        29
#
#     accuracy                           0.77        53
#    macro avg       0.80      0.79      0.77        53
# weighted avg       0.81      0.77      0.77        53

# %%
# standaryzacja

for i in ["age",'trestbps','chol','thalach']:
    print(df[i].mean())
    df[i] = (df[i] - 0)/df[i].std()

X_train,y_train = train_test_split(df,train_size=0.8)
X_zal,X_nzal = X_train['num'],X_train.drop('num', axis=1)
y_zal,y_nzal = y_train['num'],y_train.drop('num', axis=1)
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_nzal,X_zal)
pred = model.predict(y_nzal)
from sklearn.metrics import classification_report
print(classification_report(y_zal,pred))
# Out:
# 6.091383165097308
# 7.489605906270198
# 3.7891181869845347
# 5.860323501787236
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84        36
#            1       0.67      0.59      0.62        17
#
#     accuracy                           0.77        53
#    macro avg       0.74      0.72      0.73        53
# weighted avg       0.77      0.77      0.77        53

# %% [markdown]
# ### Wnioski zad 3
# nie ustandaryzowane dane dają lepsze wyniki przy klasyfikacji

# %% [markdown]
# # Wnioski
# Modele liniowe są jedne z wielu sposobów predykcji oraz klasteryzacji danych. Są one na pewno dość przydatnymi metodami z uwagi na swoją przewidywalność w działaniu oraz możliwości analizy ich działania oraz szacowania ryzyka błędów. W odróżnieniu od innych algorytmów ML są bardziej odporne na problemy overfittingu oraz braku zbierzności do globalnego minimum względem pewnej miary wykożystanej w funkcji celu. Jeżeli chodzi o zdolności ekstrapolacyjne oraz interpolacyjne regresji liniowej należy pamiętać że predykcja da zadowalające wyniki tylko w przypadku kiedy charakter danych będzie liniowy. Jeżeli taka własność danych nie występuje należy skożystać z innych algorytmów predykcyjnych lub użyć regresji nieliniowej. Przy regresji logistycznej należy pamiętać że ten algorytm podobnie jak SVM rozdziela zbiory danych na dwa podzbiory (sklasyfikowene pozytywnie i sklasyfikowane negatywnie) więc w przypadku rozdzielania zbioru danych na więcej niż dwie kategorie należy użyć więcej niż jednej regresji logistycznej zgodnie z zasadą jedna klasa kontra wszystkie inne.
