# %% [markdown]
# Michal Michniak

# %% [markdown]
# ### Zadanie 3.
# Zdefiniuj poniższą funkcję i sporządź jej wykres dla argumentów z danego przedziału:
#
# $ f(x) = x^2 + 5 $
#
# 1. $x > -1$ oraz $x < 1$
# 2. $x > -6$ oraz $x < 6$
# 3. $x > 0$ oraz $x < 5$
#
# Wspierając się dokumentacją Matplotlib. Dodaj do wykresu etykiety osi, tytuły wykresów i legendy.
#
# Wskazówki: Deklaracja funkcji w Python.
#
# W Pythonie bloki kodu (w tym również funkcje) są wyróżniane za pomocą wcięć. Do wizualizacji wyników w Pythonie używa się pakietu Matplotlib.
#
# W pliku mają być zawarte: imię, nazwisko, opis wykonywanego ćwiczenia - formatowanie markdown w poszczególnych komórkach.

# %%
from cProfile import label
import matplotlib.pyplot as plt
import numpy as np

func = lambda x: x**2 + 5
x = np.arange(-6,6,0.01)
## 1
plt.plot(x,func(x),label="f(x)=$x^2$ + 5")
plt.xlim([-1,1])
plt.ylim([0,10])
plt.title("f(x)=$x^2$ + 5")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.legend()
plt.show()

# %%
# 2
plt.plot(x,func(x),label="f(x)=$x^2$ + 5")
plt.xlim([-6,6])
plt.ylim([0,50])
plt.title("f(x)=$x^2$ + 5")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.legend()
plt.show()

# %%
# 3
plt.plot(x,func(x),label="f(x)=$x^2$ + 5")
plt.xlim([0,5])
plt.ylim([0,40])
plt.title("f(x)=$x^2$ + 5")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.legend()
plt.show()

# %% [markdown]
# ### Zadanie 4.
#
# Utwórz dataframe, w którym kolumny mają nazwy: name, surname, age, sex. Uzupełnij pięcioma dowolnymi rekordami oraz wyświetl informacje o danych pandas .info(), opis danych pandas .describe(), wyświetl pierwsze trzy rekordy pandas .head().

# %%
import numpy as np
import pandas as pd
import cmath
col = ["name", "surname", "age", "sex"]
data  = np.zeros([5,4])
data = [["Albert","Einstein",165,"Male"],
["Sylwia", "Michalska", 50, "Unknown"],
["Krzysztof", "Kononowicz", 43 ,"Male" ],
["Maria", "Skłodowska-Curie", 108, "Female"],
["Elizabeth", "Windsor", 9223372036854775807, "Female"]
]
df = pd.DataFrame(data, columns=col)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes
# None

# %%
print(df.describe())
# Out:
#                 age
# count  5.000000e+00
# mean   1.844674e+18
# std    4.124817e+18
# min    4.300000e+01
# 25%    5.000000e+01
# 50%    1.080000e+02
# 75%    1.650000e+02
# max    9.223372e+18

# %%
print(df.head(3))
# Out:
#         name     surname  age      sex
# 0     Albert    Einstein  165     Male
# 1     Sylwia   Michalska   50  Unknown
# 2  Krzysztof  Kononowicz   43     Male
