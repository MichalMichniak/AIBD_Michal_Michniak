# %% [markdown]
#  # Połączenie z bazą danych przy pomocy sqlAlchemy

# %%
import sqlalchemy
from sqlalchemy import create_engine
db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb"

db = create_engine(db_string)
connection_sqlalchemy = db.connect()

# %% [markdown]
# Zapytanie do bazy i wypisanie wyników

# %%
result_set = db.execute("SELECT * FROM city")  
for r in result_set:  
    print(r)
# Out:
# (1, 'A Corua (La Corua)', 87, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (2, 'Abha', 82, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (3, 'Abu Dhabi', 101, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (4, 'Acua', 60, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (5, 'Adana', 97, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (6, 'Addis Abeba', 31, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (7, 'Aden', 107, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (8, 'Adoni', 44, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (9, 'Ahmadnagar', 44, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (10, 'Akishima', 50, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (11, 'Akron', 103, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (12, 'al-Ayn', 101, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (13, 'al-Hawiya', 82, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (14, 'al-Manama', 11, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (15, 'al-Qadarif', 89, datetime.datetime(2006, 2, 15, 9, 45, 25))
# ...

# %% [markdown]
#  # Połączenie z bazą danych przy pomocy psycopg2 i pandas

# %%
import psycopg2 as pg
import psycopg2 as pg
import pandas as pd
connection = pg.connect(host='pgsql-196447.vipserv.org', port=5432, dbname='wbauer_adb', user='wbauer_adb', password='adb2020')

# %% [markdown]
# Zapytanie do bazy i wypisanie wyników

# %%
df = pd.read_sql('select * from film',con=connection)
print(df)
# Out:
# /home/minik/anaconda3/envs/AIBD_env/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#      film_id              title  \
# 0        133    Chamber Italian
# 1        384   Grosse Wonderful
# 2          8    Airport Pollock
# 3         98  Bright Encounters
# 4          1   Academy Dinosaur
# ..       ...                ...
# 995      996     Young Language
# 996      997         Youth Kick
# 997      998       Zhivago Core
# 998      999  Zoolander Fiction
# 999     1000          Zorro Ark
#
#                                            description  release_year  \
# 0    A Fateful Reflection of a Moose And a Husband ...          2006
# 1    A Epic Drama of a Cat And a Explorer who must ...          2006
# ...

# %% [markdown]
# ## Połączenie za pomocą sqlAlchemy i pandas

# %%
df = pd.read_sql('select * from city', con=connection_sqlalchemy)
df
# Out:
#      city_id                city  country_id         last_update
# 0          1  A Corua (La Corua)          87 2006-02-15 09:45:25
# 1          2                Abha          82 2006-02-15 09:45:25
# 2          3           Abu Dhabi         101 2006-02-15 09:45:25
# 3          4                Acua          60 2006-02-15 09:45:25
# 4          5               Adana          97 2006-02-15 09:45:25
# ..       ...                 ...         ...                 ...
# 595      596               Zaria          69 2006-02-15 09:45:25
# 596      597        Zeleznogorsk          80 2006-02-15 09:45:25
# 597      598         Zhezqazghan          51 2006-02-15 09:45:25
# 598      599            Zhoushan          23 2006-02-15 09:45:25
# 599      600          Ziguinchor          83 2006-02-15 09:45:25
#
# [600 rows x 4 columns]

# %% [markdown]
# ### Ćwiczenia:
# Wykonaj zapytania za pomocą skryptów pythona:

# %% [markdown]
# 1. Ile kategorii filmów mamy w wypożyczalni?

# %%
df = pd.read_sql('select count(DISTINCT name) from category;',con=connection_sqlalchemy)
print(f"jest {df['count'][0]} kategorii filmów")
# Out:
# jest 16 kategorii filmów

# %% [markdown]
# 2. Wyświetl listę kategorii w kolejności alfabetycznej.

# %%
df = pd.read_sql('select DISTINCT name from category Order by name asc;',con=connection_sqlalchemy)
print(df["name"])
# Out:
# 0          Action
# 1       Animation
# 2        Children
# 3        Classics
# 4          Comedy
# 5     Documentary
# 6           Drama
# 7          Family
# 8         Foreign
# 9           Games
# 10         Horror
# 11          Music
# 12            New
# 13         Sci-Fi
# 14         Sports
# 15         Travel
# Name: name, dtype: object

# %% [markdown]
# 3. Znajdź najstarszy i najmłodszy film do wypożyczenia.

# %%
df= pd.read_sql("select title from film order by release_year asc fetch first row only;",con = connection_sqlalchemy)
print(f"najstarszy film: { df['title'][0] } ")
df= pd.read_sql("select title from film order by release_year desc fetch first 1 row only;",con = connection_sqlalchemy)
print(f"najnowszy film: { df['title'][0] } ")
# Out:
# najstarszy film: Chamber Italian
# najnowszy film: Chamber Italian

# %% [markdown]
# 4. Ile wypożyczeń odbyło się między 2005-07-01 a 2005-08-01?

# %%
df= pd.read_sql(f"select count(rental_date) from rental where rental_date between '2005-07-01' and '2005-08-01'; ",con = connection_sqlalchemy)
print(f"liczba wypożyczeń : { df['count'][0]} ")
# Out:
# liczba wypożyczeń : 6709

# %% [markdown]
# 5. Ile wypożyczeń odbyło się między 2010-01-01 a 2011-02-01?

# %%
df= pd.read_sql(f"select count(rental_date) from rental where rental_date between ' 2010-01-01' and '2011-02-01'; ",con = connection_sqlalchemy)
print(f"liczba wypożyczeń : { df['count'][0]} ")
# Out:
# liczba wypożyczeń : 0

# %% [markdown]
# 6. Znajdź największą płatność wypożyczenia.

# %%
df= pd.read_sql(f"select amount from payment order by amount desc fetch first 1 row only; ",con = connection_sqlalchemy)
print(f"najwysza cena wypozyczenia : { df['amount'][0]} ")
# Out:
# najwysza cena wypozyczenia : 11.99

# %% [markdown]
# 7. Znajdź wszystkich klientów z Polski, Nigerii lub Bangladeszu.

# %%
txt = """select first_name,last_name
from customer
inner join address on customer.address_id = address.address_id 
inner join city on address.city_id = city.city_id 
inner join country on country.country_id = city.country_id
where country in ('Poland','Nigeria','Bangladesh');
"""#
df= pd.read_sql(txt,con = connection_sqlalchemy)
print(f"klienci z polski nigerii i bangladeszu: \n{ df} ")
# Out:
# klienci z polski nigerii i bangladeszu:
#    first_name  last_name
# 0       Sonia    Gregory
# 1       Brian      Wyman
# 2      Sidney   Burleson
# 3      Rodney    Moeller
# 4     Stephen     Qualls
# 5       Velma      Lucas
# 6     Marilyn       Ross
# 7       Elsie     Kelley
# 8      Gladys   Hamilton
# 9       Frank   Waggoner
# 10   Marjorie     Tucker
# 11      Carol     Garcia
# 12       Leah     Curtis
# 13      Ruben      Geary
# 14       Olga    Jimenez
# 15     Bertha   Ferguson
# 16     Tracey    Barrett
# 17         Jo     Fowler
# 18    Johnnie   Chisholm
# 19    Wallace      Slone
# 20   Michelle      Clark
# 21    Russell    Brinson
# 22     Jimmie  Eggleston
# 23  Constance       Reid

# %% [markdown]
# 8. Gdzie mieszkają członkowie personelu?

# %%
txt = """select distinct country
from staff
inner join address on staff.address_id = address.address_id 
inner join city on address.city_id = city.city_id 
inner join country on country.country_id = city.country_id
"""
df= pd.read_sql(txt,con = connection_sqlalchemy)
print(f"miejsca zamieszkania pracownikow: \n{ df['country']} ")
# Out:
# miejsca zamieszkania pracownikow:
# 0    Australia
# 1       Canada
# Name: country, dtype: object

# %% [markdown]
# 9. Ilu pracowników mieszka w Argentynie lub Hiszpanii?

# %%
txt = """select count(country)
from staff
inner join address on staff.address_id = address.address_id 
inner join city on address.city_id = city.city_id 
inner join country on country.country_id = city.country_id
where country in ('Argentina', 'Spain');
"""
df= pd.read_sql(txt,con = connection_sqlalchemy)
print(f"liczba pracownikow w hiszpani i argentynie: { df['count'][0]} ")
# Out:
# liczba pracownikow w hiszpani i argentynie: 0

# %% [markdown]
# 10. Jakie kategorie filmów zostały wypożyczone przez klientów?

# %%
txt = """select distinct category.name
from rental
inner join inventory on rental.inventory_id = inventory.inventory_id
inner join film on inventory.film_id = film.film_id
inner join film_category on film.film_id = film_category.film_id
inner join category on category.category_id = film_category.category_id
where rental_id between 0 and 100000000000000

"""
df= pd.read_sql(txt,con = connection_sqlalchemy)
print(f"{ df} ")
# Out:
#            name
# 0        Sports
# 1      Classics
# 2           New
# 3        Family
# 4        Comedy
# 5     Animation
# 6        Travel
# 7         Music
# 8         Drama
# 9        Horror
# 10       Sci-Fi
# 11        Games
# 12  Documentary
# 13      Foreign
# 14       Action
# 15     Children

# %% [markdown]
# 11. Znajdź wszystkie kategorie filmów wypożyczonych w Ameryce.

# %%
txt = """select distinct category.name
from rental
inner join inventory on rental.inventory_id = inventory.inventory_id
inner join film on inventory.film_id = film.film_id
inner join film_category on film.film_id = film_category.film_id
inner join category on category.category_id = film_category.category_id
inner join customer on customer.customer_id = rental.customer_id
inner join address on address.address_id = customer.address_id
inner join city on address.city_id = city.city_id 
inner join country on country.country_id = city.country_id
where country.country in ('United States')
"""
df= pd.read_sql(txt,con = connection_sqlalchemy)
print(f"{ df} ")
# Out:
#            name
# 0        Action
# 1     Animation
# 2      Children
# 3      Classics
# 4        Comedy
# 5   Documentary
# 6         Drama
# 7        Family
# 8       Foreign
# 9         Games
# 10       Horror
# 11        Music
# 12          New
# 13       Sci-Fi
# 14       Sports
# 15       Travel

# %% [markdown]
# 12. Znajdź wszystkie tytuły filmów, w których grał: Olympia Pfeiffer lub Julia Zellweger lub Ellen Presley

# %%
txt = """select title
from film
inner join film_actor on film_actor.film_id = film.film_id
inner join actor on film_actor.actor_id = actor.actor_id
where (actor.first_name in ('Olympia') and actor.last_name in ('Pfeiffer')) or (actor.first_name in ('Julia') and actor.last_name in ('Zellweger'))
or (actor.first_name in ('Ellen') and actor.last_name in ('Presley'))
"""
df= pd.read_sql(txt,con = connection_sqlalchemy)
print(f"{ df} ")
# Out:
#                 title
# 0     Bilko Anonymous
# 1   Caribbean Liberty
# 2    Casper Dragonfly
# 3    Empire Malkovich
# 4       Floats Garden
# ..                ...
# 64       Outlaw Hanky
# 65    Panky Submarine
# 66   Rider Caddyshack
# 67          Won Dares
# 68      Wyoming Storm
#
# [69 rows x 1 columns]
